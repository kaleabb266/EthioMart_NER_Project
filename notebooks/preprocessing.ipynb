# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalze1/Amharic_Named_Entity_Recognition/blob/task-1/notebook/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import re
sys.path.append(os.path.abspath("../scripts"))

# %%
import pandas as pd
raw_data_path = "../data/telegram_data.csv"
df = pd.read_csv(raw_data_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2692 entries, 0 to 2691
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     2692 non-null   object
#  1   Channel Username  2692 non-null   object
#  2   ID                2692 non-null   int64
#  3   Message           1943 non-null   object
#  4   Date              2692 non-null   object
#  5   Media Path        2659 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 126.3+ KB

# %%
# Drop rows with null values in the 'Message' column
df = df.dropna(subset=['Message'])

# %%
# Drop duplicate rows based on the 'Message' column
df = df.drop_duplicates(subset='Message')

# %%
num_messages = df.shape[0]
print("Number of messages:", num_messages)
# Out:
# Number of messages: 1490

# %%
import pandas as pd

pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
for message in df['Message']:
    print(message)
# Out:
# 〰️〰️〰️〰️〰️〰️〰️
# Under Armur
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,42,43
# Price   3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    42,43
# Price   3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# NB
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,42,43
# Price   2900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# High Quality shoes
# 🔸🔸🔸🔸🔸🔸
# Size    43,44
# Price   3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# Skechers
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 40,42,43
# Price  3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Jordan low
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,41,42,43
# Price  3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Air force 1 High Quality
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,43
# Price   3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# 🔥🔥Men WATCH 🔥🔥
# CLASICO
# 🔸🔸🔸🔸🔸🔸
# Price  2200( No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# GOUPU
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size  40,42
# Price  3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# 🔥🔥GOLDEN WATCH 🔥🔥
# ROLEX,CK,GUCCI,CYBER,CASENET
# 🔸🔸🔸🔸🔸🔸
# ( No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# 🔥🔥BLACK WATCH 🔥🔥
# RADO,ROLEX,CK,EMPORIO ARMANI
# 🔸🔸🔸🔸🔸🔸
# Price  2200( No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# NB
# 🔸🔸🔸🔸🔸🔸
# Size    41,42,43
# Price   3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# NB
# 🔸🔸🔸🔸🔸🔸
# Size    42,43,44
# Price   3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Jordan low
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,42
# Price  3300
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,43
# Price   3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# GOUPU
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 40,41,42,43
# Price  3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    #40
# Price   3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Puma
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,43
# Price  3600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,42,43
# Price   3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# GOUPU
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size  41,42
# Price  3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# HainoTeko Smart Watch
# 🔸🔸🔸🔸🔸🔸
#
# Price  4500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# BAPE  Start
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    42
# Price   3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# Rolex
# 🔸🔸🔸🔸🔸🔸
# Price  2200( No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️
# CLASICO
# 🔸🔸🔸🔸🔸🔸
# Price  2200( No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Puma
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 40,41,43
# Price  3600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# New year Discount
# 🌼🌼🌼🌼🌼🌼🌼🌼🌼
# 〰️〰️〰️〰️〰️
# 🔸🔸🔸🔸🔸🔸
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 🌼🌼🌼🌼🌼🌼🌼🌼🌼🌼🌼
# 〰️〰️〰️〰️〰️
# Skechers
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 42,43
# Price  3100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Reebok
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size 40,41,42
# Price  2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,41
# Price   3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Men Jacket
# Size   L , Xl ,XXL
# Price  3200
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    36,37,38,39
# Price  2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Air-force
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    40,41,42,43,45
# Price  2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# 🔸🔸🔸🔸🔸🔸
# Size   Xl
# Price  3950
# (No Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# 🔸🔸🔸🔸🔸🔸
# Size   3xl
# Price  3950
# (No Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Nike SB
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    42,43
# Price  2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Air force Supreme
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    43,44
# Price   4500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Air force XXV
# Made in Vietnam
# 🔸🔸🔸🔸🔸🔸
# Size    41,42,43
# Price   4800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     🔶 ፋሽን ተራ /Fashion Tera 🔶
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# 🛑Discount 🛑
#
# CHEKICH
# Size 42,43
# Prices 3500
# Made in Turkey
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# SPEED COUPLE WATCH
# Prices 3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# BRAND Watches
# Prices 2200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# 🎅Christmas Discount 🎅
# Air Force
# Made in  Vietnam
# Size 43,44,45
# Price 1800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 1  Low Travis scott
# Made in Vietnam
# Size  #40,42,43
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# BRAND Watches
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4 LV
# Made in Vietnam
# Price 3200,,,3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size 40,42,43,44
# Price 2300
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# NB
# Size 39,41,42
# Prices 2700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# SPEED COUPLE WATCH
# Prices 3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# BALENCIAGA
# Made in Vietnam
# Size    #40
# Prices 3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# BALENCIAGA
# Made in Vietnam
# Size    36,37,39
# Prices 2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Nike SB
# Made in Vietnam
# Size  40,41,42
# Prices 3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Skechers
# Made in Vietnam
# Size  42,43
# Prices 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# NB
# Prices 2700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Rolex (Men)
# Prices 2200 (No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# GUCCI (Men)
# Prices 2200 (No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Nike
# Made in  Vietnam
# Size 40,42,43,
# Price 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Jordan
# Size 36,38,39
# Price 2300
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4 LV
# Made in Vietnam
# Price 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size 40,41,42,43,44
# Price 2300
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# FITRON Watches (Men)
# Price 2400 (No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# BALENCIAGA
# Made in Vietnam
# Size    36,37,38,39
# Prices 2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# FITRON Watches (Men)
# Price 2300 (No gift box)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# All star
# Made in Vietnam
# Size 43
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Size 42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas Yezzy v3
# Made in Vietnam
# Size    36,37
# Price 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size 41,42
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  GIORGIO ARMANI (Men Socks)
# Price 1000 ( 5️⃣pc)
# (No Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Jordan 11
# Made in Vietnam
# Size  40,41,42,43,44
# Price 3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas Yezzy v3
# Made in Vietnam
# Size    36,37,38,39
# Price 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Force
# Made in  Vietnam
# Size 36,37,38
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 🛑Discount prices 🛑
# Vest jacket -2300-large
# Fur jacket-2900-xl
# (No delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 1  Low Travis scott
# Made in Vietnam
# Size  #42
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4
# Made in Vietnam
# Size  40,41,42
# Price 3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas
# Made in Vietnam
# Size    41,42,43
# Price 2900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 🌼🌼New Year Discount 🌼🌼
# 〰️〰️〰️〰️〰️〰️〰️
# European shoes
# MARC FISHER (Pure Leather)
# Size   #42
# Prices 6500❌ 5950✅
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 🌼🌼🌼🌼🌼🌼🌼🌼🌼🌼🌼🌼
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4
# Made in Vietnam
# Size  40,41,42,43
# Price 3200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan
# Size 40,41,42
# Price 1900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Size 41,42
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan Retro
# Made in Vietnam
# Size     42,43
# Prices 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Reebok
# Made in Vietnam
# Size  41,43
# Prices  2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# ROLEX COUPLE WATCH
# Prices 4300
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Fur Jacket
# Size Xl,2xl,4xl
# Prices 3200
# (No delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Vest Jacket
# Size Xl,2xl
# Prices 2600
# (No delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Force
# Made in  Vietnam
# Size 36,37,38
# Price 2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Force
# Made in  Vietnam
# Size 41,42
# Price 2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# VIGUER Automatic Watches (Men)
# Price 3500 (With gift box )
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Size 40,41,42,43
# Prices 3900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰〰〰〰〰〰〰
# Quality Shoes
# Size 40,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# SVETSEON COUPLE WATCH
# Prices 5700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Skechers
# Size  36,37,38
# Prices 2200
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Force
# Made in  Vietnam
# Size 40,41,42,43,44
# Price 2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Reebok
# Made in Vietnam
# Size    40,41,42,43,44
# Prices  2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# ROLEX Watches (Men)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# BALENCIAGA
# Size 41,42
# Price 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# BRAND Watches (Men)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# European shoes
# MARC FISHER (Pure Leather)
# Size   #42
# Prices 6500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  All Star Leather
# Made in Vietnam
# Size   40,41,42,43
# Prices 3400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Size 40,41,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# https://vm.tiktok.com/ZM2yHbMPH
#
#
# ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
#
# ቢሮ ቁጥር 205
#
# ስልክ  0945355266
#
# 〰〰〰〰〰
# BALENCIAGA
# Size 41,42,43,44
# Price 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Nike
# Made in  Vietnam
# Size 40,41,42,43
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Size 40,41
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# COUPLE ROLEX
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰〰〰〰〰〰〰
# Quality Shoes
# Size 39,41,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# High Quality Men Shoes
# Size 40,42,43
# Prices 3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# COUPLE SPEED
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Force
# Made in  Vietnam
# Size 40,41,42,43
# Price 2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas Cosmic
# Made in Vietnam
# Prices 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size 40,41,42,43
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Under armor
# Made in Vietnam
# Prices 2700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰〰〰〰〰〰〰
# Quality Shoes
# Size 39,41,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Skechers
# Made in  Vietnam
#  Size 40,41,42
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Size 39,40,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Brand Watches (Men)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Adidas Yezzy 700 V3
# Made in  Vietnam
# Size #39
# Price 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# High Quality Men Shoes
# Size 41,42,43
# Prices 3800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Size 40,41,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# NIKE RUN SWIFT
# Made in  Vietnam
# Size 40,41
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Rolex , MK Watches (Women 💃)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Nike
# Made in Vietnam
# Size    41,42
# Prices 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# ADIDAS  ADIPRENE
# Made in Vietnam
# Size 41,42,43
# Prices 2950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size #41
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan
# Size 40,41,,43
# Price 1900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# Nike sb
# Made in  Vietnam
# Size 40,43
# Price 2850
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Vans
# Made in  Vietnam
# Size 41,42,
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Adidas edition 1
# Made in Vietnam
# Prices 3800
# Size   40,41,42
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan
# Size 40,41,42,43
# Price 1900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# NIKE SB
# Made in  Vietnam
# Size 40,41
# Price 2400
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Nike Air Jordan
# Made in Vietnam
# Size 41,43,44
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
# Size #42
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Jordan
# Made in  Vietnam
# Size #40
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# NIKE RUN SWIFT
# Made in  Vietnam
# Size 42,43
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Sun Glasses (Women 💃)
# Price 700
# (No Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Vans
# Made in  Vietnam
# Size 41,42,43
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Jordan
# Made in  Vietnam
# Size 40,41,42,43
# Price 2000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Nike
# Made in INDONESIA
# Prices 2800
# Size 40,41,42
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Nike
# Made in INDONESIA
# Prices 2800
# Size 41,42
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# CHEKICH
# Made in Turkey
# Prices 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰〰〰〰〰〰〰
#  Size 39,41,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Vans
# Made in Vietnam
# Prices 1900
# Size 42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Skechers
# Made in  Vietnam
#  Size 40,41,42,43
# Price 2500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Reebok
# Made in  Vietnam
#  Size 40,41
# Price 2850
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Adidas Yeezy 700 v3
# Made in  Vietnam
#  Size 41,42,43
# Price 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan
# Size 41,42
# Price 1800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Nike Sb Dior
# Made in Vietnam
# Size #40
# Prices 1950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# COUPLE SPEED
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Vans
# Made in Vietnam
# Prices 1900
# Size 36,37
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Rolex Watches (Men🕺)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Force Superme
# Made in  Vietnam
# Size 42,43,44
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
# Nike
# Made in Vietnam
# Size 36,37
# Price 1900
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# Nike Tiempo
# Made in Vietnam
# Size 40,41,42
# Price 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
# ADIDAS  ADIPRENE
# Made in Vietnam
# Size 40,41,42
# Prices 2850
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan Retro 11
# Made in Vietnam
# Size 41,42,43
# Prices 3500
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Brand Watches (Women 💃)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Brand Watches (Men🕺)
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Alexander
# Size 36,37
# Price 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Nike SB
# Made in  Vietnam
# Size 40,41,
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Adidas
# Made in  Vietnam
#  Size 39,40
# Price 2700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Force
# Made in  Vietnam
#  Size 37,38,39
# Price 1950
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Adidas
# Made in  Vietnam
#  Size 39,41,42,43
# Price 2700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# https://vm.tiktok.com/ZMFyxv8Q4
# Reebok
# Made in  Vietnam
#  Size 40,41,42,43
# Price 2850
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Air Jordan
# Made in  Vietnam
# Size 38,39
# Price 2100
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Speed 💃💃
# Price 1700
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Alexander
# Size  41
# Price 2800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4
# Made in Vietnam
# Size  41
# Price 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 4
# Made in Vietnam
# Size  42,43
# Price 3000
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan
# Size 40,41,42,43
# Price 1800
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Brand Men Watch
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# Nike SB
# Made in  Vietnam
# Size 40,41,43
# Price 2600
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰〰〰〰〰〰〰〰
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰〰〰〰〰
# 〰️〰️〰️〰️〰️〰️〰️
#  Air Jordan 9
# Made in Vietnam
# Size 40,41,42,43
# (Free Delivery)
# Inbox @Hiwe5266
# ስልክ +251945355266
#
#     ♦️ ፋሽን ተራ /Fashion Tera♦️
#           〰️〰️〰️〰️〰️〰️〰️〰️
# አድራሻ: አዲስ አበባ ,ጦር ሀይሎች ድሪም ታወር 2ተኛ ፎቅ
# ቢሮ ቁጥር 205
# 〰️〰️〰️〰️〰️
# Air Jordan
# Made in  Vietnam
#  Size 40
# Price 2000
# ...
# Adidas Tabuler
# Made in Vieatnam
# Size 41,42
# Price 1350
# 📨 @Hiwe5266
# 📞 0945355266
# Nike
# Made in Vietnam
# Size 36,37
# Price 1350
# 📨 @Huwe5266
# 📞 0945355266
# All Star
# Made in Vietnam
# Size 41,42
# Price 1400
# 📨 @Hiwe5266
# 📞 0945355266
# Adidas Old School
# Made in Vietnam
# Size 42,43
# Price 1400
# 📨 @Hiwe5266
# 📞 0945355266
# Nike
# Made in Vietnam
# Size 42
# Price 1300
# Size 41,42,43
# Price 1350
# 📨@Hiwe5266
# 📞0945355266
# Nike
# Made in Vietnam
# Size 42
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Nike
# Made in Vietnam
# Size 43
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Nike
# Made in Vietnam
# Size 42
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Nike
# Made in Vietnam
# Size 40
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Nike
# Made in Vietnam
# Size 40,41
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Nike
# Made in Vietnam
# Size 41
# Price 1300
# 📨 @Hiwe5266
# 📳 0945355266
# Adidas
# Made in Vietnam
# Size 41
# Price 1400
# 📨 @Hiwe5266
# 📳 0945355266
# Vapor Max
# Made in Vietnam
# Size 37
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 39
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 40,41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 40.5
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 40
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 41,42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 42,43
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 39
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike HURACHE
# Made in Vietnam
# Size 41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 43
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike Air force
# Made in Vietnam
# Size 37
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40,41
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Adidas Yeezy
# Made in Vietnam
# Size 40,42
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 39
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Vans 3D
# Made in Vietnam
# size 40
# Price 1500
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Vans
# Made in Vietnam
# Size 40
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# TRAZER
# Price 1100
# Contact me @Hiwe5266
# Or 0945355266
# Rolex
# Price 1200
# Contact me @Hiwe5266
# Or 0945355266
# Ck women watch
# Price 900
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 40,41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 37,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40,41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 43
# Price 1300
# Contact me @Hiwe5266
# Or  0945355266
# Nike
# Made in Vietnam
# Size 40,41,42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Vans Galaxy
# Made in Vietnam
# Size 42
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Adidas old school
# Made in Vietnam
# Size 40
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# size 41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas Tubular
# Made in Vietnam
# Size 41,42
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# size  35,36
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
#
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 37,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 37,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 40
# Price 1300
# Contact me @Hiwe5266
# or 0945355266
# Puma
# Made in Vietnam
# Size 42
# Price 1300
# Contact me @Hiwe5266
# or 0945355266
# Adidas
# Made in Indonesia
# Size 43
# price 1300
# contact me @Hiwe5266
# or 0945355266
# Puma
# Made in Vietnam
# size 37,38
# price 1300
# contact me @Hiwe5266
# or 0945355266
# Adidas
# Made in Vietnam
# Size 42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 43
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made inIndonesia
# Size 41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in  Vietnam
# Size 42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Rolex
# Made in Switzerland
# Price 1400
# Contact me @Hiwe5266
# OR 0945355266
# Nike
# Made in Vietnam
# Size 42,43
# Price 1300
# Contact me  @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 36,37,38,39
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 42
# Price  1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40,41,42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Rebook
# Made in Vietnam
# Size 40,41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 39,40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size36,37,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36.37
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 35,36,37,38
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 39.40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40,41.42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 39,40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Vans
# Made in Vietnam
# Size 40
# Price 1300
# Contact @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 40
# Price 1300
# Contact @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 40
# Price 1300
# Contact @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 40
# Price 1300
# Contact @Hiwe5266
# Or 0945355266
# Adidas Old School
# Made in Indonesia
# Size 41.42,43
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Indonesia
# Size 37,38.39,40.41,42
# Price 1300
# Contact @Hiwe5266
# Or 0945355266
# Lacosta
# Made in Vietnam
# Size 40
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Rebook
# Made in Vietnam
# Size 44
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 43.5
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36
# Price 1300
# Contact me @Hiwe5266
# 0945355266
# Nike Air force
# Made in Vietnam
# Size 36,41
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas 350
# Made in Vietnam
# Size 42
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 38,39
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36,37
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 37.5
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 36,37
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36,37,38
# Price 1300
# Contact me Hiwe5266
# Or 0945355266
# Vans Old school
# Made in Vietnam
# Size 41
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike Internationalist
# Made in Vietnam
# Size 36,37
# Price 1300
# Contact me @Hiwe5266
# Or 0945355266
# Adidas
# Made in Vietnam
# Size 37
# Price 1300
# Contact me @Hiwe 3266
# Or 0945355266
# Vans Half Cab
# Made in Vietnam
# Size 41,42
# Price 1300
# Contact me @Hiwe5266
# Or 0985409401
# Vans
# Made in Vietnam
# Size 40
# Price 1300
# Contact me @Hiwe5266
# Or 0985409401
# Sold out
# Nike Air force
# Made in Vietnam
# Size 41,42
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike Air force
# Made in Vietnam
# Size 44
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 43
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 44
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Adidas Stan Smith
# Made in Vietnam
# Size 41, 42
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Adidas Super Star
# Made in Vietnam
# Size 41, 42, 43
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# ጫማ ለመግዛት መርካቶ እየሄዱ ደክመዋል?? እንግዲያውስ ቻናላችንን በመቀላቀለ የፈለጉትን ጫማ ይዘዙን ባሉበት እናመጣለን👇👇👇👇👇👇
# https://t.me/joinchat/AAAAAEYRIOB5_Tt7gKGGjA
# Adidas Stan Smith
# Made in Vietnam
# Size 40
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike Hurache
# Made in Vietnam
# Size 38
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 36
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Adidas super star
# Made in Vietnam
# Size 43
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Puma
# Made in Vietnam
# Size 40, 41
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike HURACHE
# Made in Vietnam
# Size 43
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike
# Made in Vietnam
# Size 45
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nike HURACHE
# Made in Vietnam
# Size 40, 41
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Air force
# Made in Vietnam
# Size 44
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266
# Nikon
# D9 Digital Camera
# Price 16000
# Contact me @Hiwe5266
# Or 0945355266
# Vans Leather
# Made in Vietnam
# Size 40, 41
# Price 1400
# Contact me @Hiwe5266
# Or 0945355266
# Samsung TV
# Curved Full HD
# 55 Inch
# Price 36000
# Contact me @Hiwe5266
# Or 0945355266
# Rebook
# Made in Vietnam
# Size 41
# Price 1350
# Contact me @Hiwe5266
# Or 0945355266

# %%
# Define a function to clean and tokenize the message column
def clean_and_tokenize_amharic_message(text):
    # Regular expression to match Amharic characters (\u1200-\u137F) and numbers (0-9)
    pattern = re.compile(r'[^\u1200-\u137F0-9]+')
    # Substitute the unwanted characters with an empty string
    cleaned_text = re.sub(pattern, ' ', str(text))
    # Tokenize by splitting based on spaces
    tokens = cleaned_text.split()
    # Join tokens with commas
    tokenized_text = ','.join(tokens)
    return tokenized_text

# Apply the cleaning and tokenizing function to the 'message' column
df['cleaned_tokenized_message'] = df['Message'].apply(clean_and_tokenize_amharic_message)

# %%
# Function to check if a message contains only numeric tokens
def is_numeric_only(text):
    # Split the text by commas and spaces
    tokens = re.split(r'[,\s]+', text)
    # Check if all tokens are numeric
    return all(token.isdigit() for token in tokens if token)

# Apply the function to filter out rows where 'cleaned_tokenized_message' is numeric-only
df_filtered = df[~df['cleaned_tokenized_message'].apply(is_numeric_only)]

# %%
df_filtered.to_csv('../data/filtered_cleaned_tokenized_dataset.csv', index=False)

# %%
import pandas as pd
import re

# Load your filtered tokenized dataset
df = pd.read_csv('../data/filtered_cleaned_tokenized_dataset.csv')  # Adjust the file path accordingly



# Define the labeling function for tokenized messages
# Define the labeling function for tokenized messages
def label_tokenized_message(message):
    labeled_tokens = []


    # Extended list of product-related terms
    extended_product_list = [
    # Electronics and Accessories
    "የሞባይል", "ስልክ", "ማስታወቂያ", "በቅት",
    "መለዋወጫዎች", "የታክስ", "የኮምፒውተር", "መጋራዣ",
    "የጆሮ", "ማዳመጫዎች", "ማድረጊያዎች", "የካምን",
    "የኃይል", "ባንኮች", "ሻገር", "መተንሳሸያ",
    "የጨዋታ", "መቆጣጠሪያዎች", "መቆጣጠሪያ", "የጨዋታ",
    # Fashion and Accessories
    "የልብስ", "መለዋወጫዎች", "እምቦርጫ", "ሱሪ",
    "የጫማ", "መለዋወጫዎች", "ቦርሳዎች", "ኪስ",
    "መነጽሮች", "መነጽር", "ሻርባ", "ሽንት",
    "ጌጣጌጦች", "ስቶን", "ታብለት", "እቃዎች",
    # Home and Living
    "የቤት", "ማስጌጫዎች", "የሻንጣ", "ዕቃዎች",
    "የኩሽና", "መሳሪያዎች", "ተንበሳ", "መቀመጫ",
    "የመኝታ", "ቤት", "እቃዎች", "መኝታው",
    "የመታጠቢያ", "ቤት", "እቃዎች", "መታጠቢያ",
    "የሰሌዳ", "መኮተል", "እንደዚህ", "መሣሪያ",
    # Beauty and Personal Care
    "የፀጉር", "መዋቢያዎች", "ቆዳ", "እንክብካቤ",
    "የቆዳ", "እንክብካቤ", "ምርቶች", "መሳሪያዎች",
    "የመዋቢያ", "ብሩሾች", "ቀንሳብ", "መዋቢያዎች",
    "የጥፍር", "መዋቢያዎች", "ማደራቻ", "የአፍ",
    # Books, Stationery, and Office Supplies
    "የመጽሐፍ", "መያዣዎች", "ማህደር", "መጻፊያ",
    "የጽሕፈት", "መሳሪያዎች", "ኮምፒውተር", "የመጽሐፍት",
    "የስዕል", "መሳሪያዎች", "ዕቃዎች", "ወረቀት",
    # Food, Drinks, and Kitchenware
    "የምግብ", "ቅመሞች", "ቀመር", "ቀመራ",
    "የመጠጥ", "ዕቃዎች", "መጠጥ", "መብራር",
    "የምግብ", "ማሸጊያዎች", "እንቁላል", "ወተት",
    # Gifts, Cards, and Toys
    "የስጦታ", "ካርዶች", "ስጦታ", "ካርድ",
    "የጨዋታዎች", "መጫወቻ", "ተጫዋች", "መሳሪያዎች",
    # Sports and Outdoor
    "የስፖርት", "እቃዎች", "ኳስ", "የእንጨት",
    "መሳሪያዎች", "ስፖርት", "የመውዳት", "ዕቃዎች",
    # Other Miscellaneous Items
    "የቤት", "እቃዎች", "መጋረጃ", "የእርሻ",
    "መሳሪያ", "የትራንስፖርት", "እቃዎች", "መቀመጫ",
    "የማሽን", "የንጽህና", "መሳሪያዎች", "መጠቀሚያ",
    "የቤት", "እቃዎች", "የሰንሰለት", "መሳሪያዎች",
    "ቤት", "የስነስርት", "መሳሪያዎች", "እቃዎች",
    "የመኪና", "እቃዎች", "የጉልበት", "መዋቢያዎች","ፌሮ"
]


    # Split the message by commas (since it's already tokenized)
    tokens = message.split(',')

    i_loc_count = 0  # Counter to track labeling after B-LOC
    b_product_flag = False  # To track if the last token was a B-PRODUCT

    for i, token in enumerate(tokens):
        token = token.strip()  # Remove extra whitespace from token

        # Label B-PRODUCT if the token matches the list or is the first token
        if token   in extended_product_list:
            labeled_tokens.append(f"{token} B-PRODUCT")
            b_product_flag = True
        # Label I-PRODUCT if it comes after B-PRODUCT or is in the I-PRODUCT list
        elif b_product_flag and token in extended_product_list:
            labeled_tokens.append(f"{token} I-PRODUCT")
            b_product_flag = False  # Reset the flag after labeling I-PRODUCT
        # Label B-PRICE if it contains 'ዋጋ'
        elif 'ዋጋ' in token:
            labeled_tokens.append(f"{token} B-PRICE")
        # Label I-PRICE if it comes exactly after B-PRICE or contains 'ብር'
        elif (i > 0 and labeled_tokens[-1].endswith("B-PRICE")) or ('ብር' in token):
            labeled_tokens.append(f"{token} I-PRICE")
        # Label B-LOC if token matches location keyword
        elif token in ["አድራሻ"]:
            labeled_tokens.append(f"{token} B-LOC")
            i_loc_count = 6  # Set counter to label the next three tokens as I-LOC
        # Label the next three tokens after B-LOC as I-LOC
        elif i_loc_count > 0:
            labeled_tokens.append(f"{token} I-LOC")
            i_loc_count -= 1
        # Label specific tokens as I-LOC
        elif token in ["አዲስ", "አበባ", "ከተማ", "አቃቂ", "ቃሊቲ", "አራዳ", "ቦሌ", "ጉለሌ", "ቂርቆስ",
                       "ኮልፌ ቀራኒዮ", "ልደታ", "ንፋስ ስልክ-ላፍቶ", "የካ"]:
            labeled_tokens.append(f"{token} I-LOC")
        # Label tokens starting with '09' and having more than 7 characters as 'O'
        elif token.startswith('09') and len(token) > 7:
            labeled_tokens.append(f"{token} O")
        # For other tokens, label them as part of the product or as "O"
        else:
            labeled_tokens.append(f"{token} O")

    return "\n".join(labeled_tokens)

# Apply the labeling function to the 'cleaned_tokenized_message' column
df['Labeled_Message'] = df['cleaned_tokenized_message'].apply(label_tokenized_message)

# Save the labeled dataset in CoNLL format
with open('../data/labeled_cleaned_tokenized_dataset.conll', 'w', encoding='utf-8') as f:
    for labeled_message in df['Labeled_Message']:
        f.write(labeled_message + "\n\n")

print("NER labeling completed and saved in 'labeled_cleaned_tokenized_dataset.conll'.")
# Out:
# NER labeling completed and saved in 'labeled_cleaned_tokenized_dataset.conll'.
